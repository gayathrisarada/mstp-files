# %%
import pandas as pd
iris=pd.read_csv("iris.csv")
print(iris)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-69405259017e> in <module>
#       1 import pandas as pd
# ----> 2 iris=pd.read_csv("iris.csv")
#       3 print(iris)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %% [markdown]
# ## 10/2/20

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(bird,hue = 'type')
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\APSSDC\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
bird=pd.read_csv('bird data.csv')
bird.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84   SW
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01   SW
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34   SW
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41   SW
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13   SW

# %%
bird.isnull().sum()
# Out:
# id       0
# huml     1
# humw     1
# ulnal    3
# ulnaw    2
# feml     2
# femw     1
# tibl     2
# tibw     1
# tarl     1
# tarw     1
# type     0
# dtype: int64

# %%
bird.dropna(inplace=True)
bird.isnull().sum()
# Out:
# id       0
# huml     0
# humw     0
# ulnal    0
# ulnaw    0
# feml     0
# femw     0
# tibl     0
# tibw     0
# tarl     0
# tarw     0
# type     0
# dtype: int64

# %%
bird.duplicated().sum()
# Out:
# 0

# %%
bird.drop_duplicates()
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %%
bird['type'].value_counts()
# Out:
# 2    124
# 3    116
# 5     64
# 1     48
# 0     38
# 4     23
# Name: type, dtype: int64

# %%
x = bird.drop('type',axis=1)
y = bird['type']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x,y)
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\APSSDC\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
from sklearn.preprocessing import LabelEncoder
Ibc=LabelEncoder()
#bird['type']=Ibc.fit_transform(bird['type'])
bird.head()
# Out:
#    id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  type
# 0   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84     3
# 1   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01     3
# 2   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34     3
# 3   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41     3
# 4   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13     3

# %% [markdown]
# Each bird has a label for its ecological group:
#
#   . sw:SWIMMING BIRDS
#
#   . w:WADING BIRDS
#
#   . t:TERRESTIAL BIRDS
#
#   . r:RAPTORS
#
#   . p:SCANSORIAL BIRDS
#
#   . so:SINGING BIRDS
#
#   ## ACKOWLEDGEMENTS
#
#  This dataset is provided by Dr.D.Liu of Beijing Museum of Natural History

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf=DecisionTreeClassifier()
tree_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
Y_pred = tree_clf.predict(x_test)
from sklearn.metrics import confusion_matrix,accuracy_score

confusion_matrix(y_test,Y_pred)
# Out:
# array([[12,  0,  0,  0,  0,  0],
#        [ 0,  8,  0,  0,  0,  0],
#        [ 0,  0, 40,  0,  0,  0],
#        [ 0,  0,  0, 44,  0,  0],
#        [ 0,  0,  0,  0,  6,  0],
#        [ 0,  0,  0,  1,  0, 13]], dtype=int64)

# %%
accuracy_score(y_test,Y_pred)
# Out:
# 0.9919354838709677

# %%
C:\Users\APSSDC\Desktop\gayathri250\graphviz-2.38\release\bin
# Out:
#   File "<ipython-input-50-6d00c59aa7a6>", line 1
#     C:\Users\APSSDC\Desktop\gayathri250\graphviz-2.38\release\bin
#                                                                  ^
# SyntaxError: unexpected character after line continuation character

# %%
import os
os.environ['PATH']+=';'+r'C:\Users\APSSDC\Desktop\gayathri250\graphviz-2.38\release\bin'

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cls_names = bird.type.value_counts().index
cls_names
# Out:
# Index(['SO', 'SW', 'W', 'R', 'P', 'T'], dtype='object')

# %%
 from sklearn.tree import export_graphviz
    
export_graphviz(tree_clf,out_file='bird.dot',class_names=cls_names,rounded=True,filled=True)

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus

# %%
dot_data= StringIO()
export_graphviz(tree_clf,out_file=dot_data,filled=True,rounded=True,feature_names=x_train.columns,class_names=str(cls_names))
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## 12-02-20

# %%
import pandas as pd

df=pd.read_csv('Drug.csv')
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
from sklearn.preprocessing import LabelEncoder
lbc=LabelEncoder()
df['Age']=lbc.fit_transform(df['Age'])
df['Sex']=lbc.fit_transform(df['Sex'])
df['BP']=lbc.fit_transform(df['BP'])
df['Cholesterol']=lbc.fit_transform(df['Cholesterol'])
df['Na_to_K']=lbc.fit_transform(df['Na_to_K'])

df.head()
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0    8    0   0            0      167  drugY
# 1   30    1   1            0       89  drugC
# 2   30    1   1            0       43  drugC
# 3   12    0   2            0       10  drugX
# 4   44    0   1            0      133  drugY

# %%
df['Drug'].value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
x=df.drop('Drug',axis=1)
y=df['Drug']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf=DecisionTreeClassifier()
tree_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
y_pred=tree_clf.predict(x_test)

# %%
y_pred
# Out:
# array(['drugX', 'drugY', 'drugX', 'drugC', 'drugY', 'drugY', 'drugY',
#        'drugX', 'drugA', 'drugX', 'drugA', 'drugX', 'drugY', 'drugA',
#        'drugB', 'drugY', 'drugB', 'drugX', 'drugC', 'drugY', 'drugB',
#        'drugX', 'drugX', 'drugY', 'drugY', 'drugY', 'drugC', 'drugX',
#        'drugY', 'drugX', 'drugY', 'drugC', 'drugC', 'drugY', 'drugA',
#        'drugY', 'drugX', 'drugA', 'drugY', 'drugA', 'drugX', 'drugX',
#        'drugX', 'drugY', 'drugY', 'drugC', 'drugY', 'drugY', 'drugY',
#        'drugX', 'drugX', 'drugY', 'drugX', 'drugY', 'drugX', 'drugY',
#        'drugA', 'drugY', 'drugY', 'drugY'], dtype=object)

# %%
Y_pred=tree_clf.predict(x_test)

# %%
Y_pred
# Out:
# array(['drugX', 'drugY', 'drugX', 'drugC', 'drugY', 'drugY', 'drugY',
#        'drugX', 'drugA', 'drugX', 'drugA', 'drugX', 'drugY', 'drugA',
#        'drugB', 'drugY', 'drugB', 'drugX', 'drugC', 'drugY', 'drugB',
#        'drugX', 'drugX', 'drugY', 'drugY', 'drugY', 'drugC', 'drugX',
#        'drugY', 'drugX', 'drugY', 'drugC', 'drugC', 'drugY', 'drugA',
#        'drugY', 'drugX', 'drugA', 'drugY', 'drugA', 'drugX', 'drugX',
#        'drugX', 'drugY', 'drugY', 'drugC', 'drugY', 'drugY', 'drugY',
#        'drugX', 'drugX', 'drugY', 'drugX', 'drugY', 'drugX', 'drugY',
#        'drugA', 'drugY', 'drugY', 'drugY'], dtype=object)

# %%
Y_pred = tree_clf.predict(x_test)
from sklearn.metrics import confusion_matrix,accuracy_score

confusion_matrix(y_test,Y_pred)
# Out:
# array([[ 7,  0,  0,  0,  0],
#        [ 0,  3,  0,  0,  0],
#        [ 0,  0,  6,  0,  0],
#        [ 0,  0,  0, 18,  0],
#        [ 0,  0,  0,  0, 26]], dtype=int64)

# %%
accuracy_score(y_test,Y_pred)
# Out:
# 1.0

# %%
import os
os.environ['PATH']+=';'+r'C:\Users\APSSDC\Desktop\gayathri250\graphviz-2.38\release\bin'

# %%
pip install pydotplus
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cls_names = df.Drug.value_counts().index
cls_names
# Out:
# Index(['drugY', 'drugX', 'drugA', 'drugC', 'drugB'], dtype='object')

# %%
 from sklearn.tree import export_graphviz
    
export_graphviz(tree_clf,out_file='df.dot',class_names=cls_names,rounded=True,filled=True)

# %%
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus

# %%
dot_data= StringIO()
export_graphviz(tree_clf,out_file=dot_data,filled=True,rounded=True,feature_names=x_train.columns,class_names=str(cls_names))
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
import pandas as pd

df=pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 1.0
